# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth and the fact that it is summer in the southern hemisphere at this time of year.
# * There is no strong relationship between latitude and humidity. However, it is surprising to see that a large proportion of cities have high humidity levels within the band between 80% and 100% humidity.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that there are strong bands of cities sitting at 0, 20, 40, about 75, and about 95% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, there seem to be stronger wind speeds the further away from the equator.

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List
#
# - Randomly select at least 500 unique (non-repeat) cities based on latitude and longitude

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 599

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build partial query URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

# set up lists to hold reponse info
city = []
country = []
time_data = []
latitude = []
longitude = []
temperature = []
humidity = []
cloudiness = []
wind_speed = []

# %%
# Loop through the list of cities and perform a request for data on each
print("Beginning Data Retrieval")
print("-----------------------------")
for i in range(len(cities)):
    response = requests.get(query_url + cities[i]).json()
    try:
        print(f"Processing record {i} of {len(cities)-1} | {cities[i]}")
        city.append(response['name'])
        country.append(response['sys']['country'])
        time_data.append(response['dt'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        temperature.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
    except KeyError:
        print("City not found. Skipping...")
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 0 of 598 | dikson
# Processing record 1 of 598 | port alfred
# Processing record 2 of 598 | tubuala
# Processing record 3 of 598 | taoudenni
# Processing record 4 of 598 | verkhnyaya inta
# Processing record 5 of 598 | ankpa
# Processing record 6 of 598 | puerto ayora
# Processing record 7 of 598 | warri
# Processing record 8 of 598 | kruisfontein
# Processing record 9 of 598 | mar del plata
# Processing record 10 of 598 | saint-philippe
# Processing record 11 of 598 | hobart
# Processing record 12 of 598 | klaksvik
# Processing record 13 of 598 | tuktoyaktuk
# Processing record 14 of 598 | grand gaube
# Processing record 15 of 598 | kirakira
# Processing record 16 of 598 | bredasdorp
# Processing record 17 of 598 | georgetown
# Processing record 18 of 598 | atuona
# Processing record 19 of 598 | port elizabeth
# Processing record 20 of 598 | taolanaro
# City not found. Skipping...
# Processing record 21 of 598 | alice springs
# Processing record 22 of 598 | albany
# Processing record 23 of 598 | deputatskiy
# Processing record 24 of 598 | poum
# Processing record 25 of 598 | busselton
# Processing record 26 of 598 | mataura
# Processing record 27 of 598 | ushuaia
# Processing record 28 of 598 | jamkhandi
# Processing record 29 of 598 | ampanihy
# Processing record 30 of 598 | tilichiki
# Processing record 31 of 598 | chokurdakh
# Processing record 32 of 598 | longyearbyen
# Processing record 33 of 598 | tarbagatay
# Processing record 34 of 598 | tual
# Processing record 35 of 598 | cape town
# Processing record 36 of 598 | nizhneyansk
# City not found. Skipping...
# Processing record 37 of 598 | youghal
# Processing record 38 of 598 | rognan
# Processing record 39 of 598 | krasnik
# Processing record 40 of 598 | umzimvubu
# City not found. Skipping...
# Processing record 41 of 598 | tabas
# Processing record 42 of 598 | mount isa
# Processing record 43 of 598 | muravlenko
# Processing record 44 of 598 | mizdah
# Processing record 45 of 598 | tasiilaq
# Processing record 46 of 598 | narsaq
# Processing record 47 of 598 | pingdingshan
# Processing record 48 of 598 | nantucket
# Processing record 49 of 598 | luderitz
# Processing record 50 of 598 | carnarvon
# Processing record 51 of 598 | cidreira
# Processing record 52 of 598 | illoqqortoormiut
# City not found. Skipping...
# Processing record 53 of 598 | spassk-dalniy
# Processing record 54 of 598 | gamba
# Processing record 55 of 598 | matiri
# Processing record 56 of 598 | port hardy
# Processing record 57 of 598 | punta alta
# Processing record 58 of 598 | yellowknife
# Processing record 59 of 598 | katsuura
# Processing record 60 of 598 | hilo
# Processing record 61 of 598 | ahipara
# Processing record 62 of 598 | avarua
# Processing record 63 of 598 | olafsvik
# City not found. Skipping...
# Processing record 64 of 598 | hasaki
# Processing record 65 of 598 | nanakuli
# Processing record 66 of 598 | tarauaca
# Processing record 67 of 598 | paragould
# Processing record 68 of 598 | bethel
# Processing record 69 of 598 | ancud
# Processing record 70 of 598 | upington
# Processing record 71 of 598 | canela
# Processing record 72 of 598 | hervey bay
# Processing record 73 of 598 | saskylakh
# Processing record 74 of 598 | butaritari
# Processing record 75 of 598 | taonan
# Processing record 76 of 598 | kaili
# Processing record 77 of 598 | san patricio
# Processing record 78 of 598 | fukue
# Processing record 79 of 598 | rikitea
# Processing record 80 of 598 | souillac
# Processing record 81 of 598 | miram shah
# Processing record 82 of 598 | jobabo
# Processing record 83 of 598 | pontianak
# Processing record 84 of 598 | kilindoni
# Processing record 85 of 598 | yar-sale
# Processing record 86 of 598 | kapaa
# Processing record 87 of 598 | sao filipe
# Processing record 88 of 598 | vaitupu
# City not found. Skipping...
# Processing record 89 of 598 | hermanus
# Processing record 90 of 598 | sao joao da barra
# Processing record 91 of 598 | thies
# Processing record 92 of 598 | salalah
# Processing record 93 of 598 | limbang
# Processing record 94 of 598 | jamestown
# Processing record 95 of 598 | clackmannan
# Processing record 96 of 598 | makat
# Processing record 97 of 598 | tumen
# Processing record 98 of 598 | prince rupert
# Processing record 99 of 598 | tautira
# Processing record 100 of 598 | attawapiskat
# City not found. Skipping...
# Processing record 101 of 598 | haines junction
# Processing record 102 of 598 | nenjiang
# Processing record 103 of 598 | lungi
# Processing record 104 of 598 | hatillo
# Processing record 105 of 598 | hirtshals
# Processing record 106 of 598 | bristol
# Processing record 107 of 598 | chaihe
# Processing record 108 of 598 | belushya guba
# City not found. Skipping...
# Processing record 109 of 598 | hami
# Processing record 110 of 598 | vaitape
# Processing record 111 of 598 | ruiz
# Processing record 112 of 598 | new norfolk
# Processing record 113 of 598 | himora
# City not found. Skipping...
# Processing record 114 of 598 | hobyo
# Processing record 115 of 598 | arraial do cabo
# Processing record 116 of 598 | boa vista
# Processing record 117 of 598 | hearst
# Processing record 118 of 598 | chabahar
# Processing record 119 of 598 | barawe
# City not found. Skipping...
# Processing record 120 of 598 | caravelas
# Processing record 121 of 598 | castro
# Processing record 122 of 598 | chuy
# Processing record 123 of 598 | koungou
# City not found. Skipping...
# Processing record 124 of 598 | bambous virieux
# Processing record 125 of 598 | nome
# Processing record 126 of 598 | ewa beach
# Processing record 127 of 598 | ribeira grande
# Processing record 128 of 598 | sydney
# Processing record 129 of 598 | skjervoy
# Processing record 130 of 598 | valdivia
# Processing record 131 of 598 | sitka
# Processing record 132 of 598 | pochutla
# Processing record 133 of 598 | barrow
# Processing record 134 of 598 | bluff
# Processing record 135 of 598 | hithadhoo
# Processing record 136 of 598 | conde
# Processing record 137 of 598 | sayyan
# Processing record 138 of 598 | fort frances
# Processing record 139 of 598 | victor harbor
# Processing record 140 of 598 | koumac
# Processing record 141 of 598 | opuwo
# Processing record 142 of 598 | liberia
# Processing record 143 of 598 | vohibinany
# Processing record 144 of 598 | ilulissat
# Processing record 145 of 598 | teshie
# Processing record 146 of 598 | abiy adi
# City not found. Skipping...
# Processing record 147 of 598 | imisli
# City not found. Skipping...
# Processing record 148 of 598 | meulaboh
# Processing record 149 of 598 | khatanga
# Processing record 150 of 598 | pontes e lacerda
# Processing record 151 of 598 | vilhena
# Processing record 152 of 598 | bidar
# Processing record 153 of 598 | copala
# Processing record 154 of 598 | ponta do sol
# Processing record 155 of 598 | canoinhas
# Processing record 156 of 598 | itoman
# Processing record 157 of 598 | la asuncion
# Processing record 158 of 598 | kavieng
# Processing record 159 of 598 | rawson
# Processing record 160 of 598 | virar
# Processing record 161 of 598 | tromso
# Processing record 162 of 598 | saleaula
# City not found. Skipping...
# Processing record 163 of 598 | dunedin
# Processing record 164 of 598 | egvekinot
# Processing record 165 of 598 | guerrero negro
# Processing record 166 of 598 | wahran
# City not found. Skipping...
# Processing record 167 of 598 | san cristobal
# Processing record 168 of 598 | grand river south east
# City not found. Skipping...
# Processing record 169 of 598 | pangnirtung
# Processing record 170 of 598 | cherskiy
# Processing record 171 of 598 | aguimes
# Processing record 172 of 598 | dzhusaly
# City not found. Skipping...
# Processing record 173 of 598 | zelenogorskiy
# Processing record 174 of 598 | jambi
# Processing record 175 of 598 | andenes
# City not found. Skipping...
# Processing record 176 of 598 | qaanaaq
# Processing record 177 of 598 | portland
# Processing record 178 of 598 | ulladulla
# Processing record 179 of 598 | preeceville
# Processing record 180 of 598 | punta arenas
# Processing record 181 of 598 | mareeba
# Processing record 182 of 598 | duz
# City not found. Skipping...
# Processing record 183 of 598 | bac lieu
# City not found. Skipping...
# Processing record 184 of 598 | lebu
# Processing record 185 of 598 | blonduos
# City not found. Skipping...
# Processing record 186 of 598 | sholavandan
# City not found. Skipping...
# Processing record 187 of 598 | tsihombe
# City not found. Skipping...
# Processing record 188 of 598 | santarem
# City not found. Skipping...
# Processing record 189 of 598 | samusu
# City not found. Skipping...
# Processing record 190 of 598 | upernavik
# Processing record 191 of 598 | zamora
# Processing record 192 of 598 | hamilton
# Processing record 193 of 598 | ventosa
# Processing record 194 of 598 | mys shmidta
# City not found. Skipping...
# Processing record 195 of 598 | palmerston
# Processing record 196 of 598 | kaberamaido
# Processing record 197 of 598 | viedma
# Processing record 198 of 598 | honiara
# Processing record 199 of 598 | soyo
# Processing record 200 of 598 | cabedelo
# Processing record 201 of 598 | acacias
# Processing record 202 of 598 | ximei
# Processing record 203 of 598 | kavaratti
# Processing record 204 of 598 | mount gambier
# Processing record 205 of 598 | ascension
# City not found. Skipping...
# Processing record 206 of 598 | vaini
# Processing record 207 of 598 | bosanski brod
# Processing record 208 of 598 | great yarmouth
# Processing record 209 of 598 | college
# Processing record 210 of 598 | avera
# Processing record 211 of 598 | gilbues
# Processing record 212 of 598 | port keats
# Processing record 213 of 598 | airai
# Processing record 214 of 598 | cayenne
# Processing record 215 of 598 | belmonte
# Processing record 216 of 598 | barranca
# Processing record 217 of 598 | tabarqah
# City not found. Skipping...
# Processing record 218 of 598 | jinka
# Processing record 219 of 598 | morgan city
# Processing record 220 of 598 | shelburne
# Processing record 221 of 598 | hendek
# Processing record 222 of 598 | camana
# City not found. Skipping...
# Processing record 223 of 598 | presidencia roque saenz pena
# Processing record 224 of 598 | zhangye
# Processing record 225 of 598 | ganzhou
# Processing record 226 of 598 | mahadday weyne
# City not found. Skipping...
# Processing record 227 of 598 | udachnyy
# Processing record 228 of 598 | flinders
# Processing record 229 of 598 | hofn
# Processing record 230 of 598 | louisbourg
# City not found. Skipping...
# Processing record 231 of 598 | mahebourg
# Processing record 232 of 598 | van
# Processing record 233 of 598 | mastic beach
# Processing record 234 of 598 | hambantota
# Processing record 235 of 598 | tonantins
# Processing record 236 of 598 | minab
# Processing record 237 of 598 | honggang
# Processing record 238 of 598 | itarema
# Processing record 239 of 598 | hualmay
# Processing record 240 of 598 | el alto
# Processing record 241 of 598 | awjilah
# Processing record 242 of 598 | lorengau
# Processing record 243 of 598 | grindavik
# Processing record 244 of 598 | nanortalik
# Processing record 245 of 598 | cockburn town
# Processing record 246 of 598 | bargal
# City not found. Skipping...
# Processing record 247 of 598 | bosaso
# Processing record 248 of 598 | vanimo
# Processing record 249 of 598 | calabozo
# Processing record 250 of 598 | alofi
# Processing record 251 of 598 | sentyabrskiy
# City not found. Skipping...
# Processing record 252 of 598 | monrovia
# Processing record 253 of 598 | clyde river
# Processing record 254 of 598 | acapulco
# Processing record 255 of 598 | calmar
# Processing record 256 of 598 | buala
# Processing record 257 of 598 | kabalo
# Processing record 258 of 598 | inta
# Processing record 259 of 598 | glendive
# Processing record 260 of 598 | barentsburg
# City not found. Skipping...
# Processing record 261 of 598 | mandalgovi
# Processing record 262 of 598 | vila franca do campo
# Processing record 263 of 598 | skalistyy
# City not found. Skipping...
# Processing record 264 of 598 | port lincoln
# Processing record 265 of 598 | luwuk
# Processing record 266 of 598 | parkersburg
# Processing record 267 of 598 | cumberland
# Processing record 268 of 598 | roma
# Processing record 269 of 598 | lakatoro
# Processing record 270 of 598 | half moon bay
# Processing record 271 of 598 | kenora
# Processing record 272 of 598 | gallup
# Processing record 273 of 598 | east london
# Processing record 274 of 598 | stephenville
# Processing record 275 of 598 | thompson
# Processing record 276 of 598 | tiksi
# Processing record 277 of 598 | turukhansk
# Processing record 278 of 598 | severnoye
# Processing record 279 of 598 | cam ranh
# Processing record 280 of 598 | sechelt
# Processing record 281 of 598 | pakokku
# Processing record 282 of 598 | bela
# Processing record 283 of 598 | arrecife
# City not found. Skipping...
# Processing record 284 of 598 | lagoa
# Processing record 285 of 598 | abha
# Processing record 286 of 598 | geraldton
# Processing record 287 of 598 | pevek
# Processing record 288 of 598 | qingdao
# Processing record 289 of 598 | deniliquin
# Processing record 290 of 598 | merauke
# Processing record 291 of 598 | yatou
# Processing record 292 of 598 | huilong
# Processing record 293 of 598 | severo-kurilsk
# Processing record 294 of 598 | labuhan
# Processing record 295 of 598 | talara
# Processing record 296 of 598 | sataua
# City not found. Skipping...
# Processing record 297 of 598 | rio grande
# Processing record 298 of 598 | dalton
# Processing record 299 of 598 | nikolskoye
# Processing record 300 of 598 | toamasina
# Processing record 301 of 598 | kamaishi
# Processing record 302 of 598 | henties bay
# Processing record 303 of 598 | ukiah
# Processing record 304 of 598 | quatre cocos
# Processing record 305 of 598 | asau
# City not found. Skipping...
# Processing record 306 of 598 | sergeyevka
# Processing record 307 of 598 | sorong
# Processing record 308 of 598 | nishihara
# Processing record 309 of 598 | norman wells
# Processing record 310 of 598 | vestmannaeyjar
# Processing record 311 of 598 | solnechnyy
# Processing record 312 of 598 | zangakatun
# Processing record 313 of 598 | bereda
# Processing record 314 of 598 | pangai
# Processing record 315 of 598 | ayan
# Processing record 316 of 598 | belle fourche
# Processing record 317 of 598 | zacualpan
# Processing record 318 of 598 | nara
# Processing record 319 of 598 | teknaf
# Processing record 320 of 598 | front royal
# Processing record 321 of 598 | bandarbeyla
# Processing record 322 of 598 | richards bay
# Processing record 323 of 598 | borger
# Processing record 324 of 598 | coahuayana
# Processing record 325 of 598 | kamenskoye
# City not found. Skipping...
# Processing record 326 of 598 | iqaluit
# Processing record 327 of 598 | torbay
# Processing record 328 of 598 | cabo san lucas
# Processing record 329 of 598 | dasoguz
# Processing record 330 of 598 | pemangkat
# City not found. Skipping...
# Processing record 331 of 598 | coihaique
# Processing record 332 of 598 | chagda
# City not found. Skipping...
# Processing record 333 of 598 | lubaczow
# Processing record 334 of 598 | jizan
# Processing record 335 of 598 | rudnichnyy
# Processing record 336 of 598 | kitimat
# Processing record 337 of 598 | sao felix do xingu
# Processing record 338 of 598 | harper
# Processing record 339 of 598 | bathsheba
# Processing record 340 of 598 | nelson bay
# Processing record 341 of 598 | caarapo
# Processing record 342 of 598 | bubaque
# Processing record 343 of 598 | brae
# Processing record 344 of 598 | paamiut
# Processing record 345 of 598 | bairiki
# City not found. Skipping...
# Processing record 346 of 598 | axim
# Processing record 347 of 598 | port macquarie
# Processing record 348 of 598 | kysyl-syr
# Processing record 349 of 598 | rorvik
# Processing record 350 of 598 | padang
# Processing record 351 of 598 | zhezkazgan
# Processing record 352 of 598 | khorinsk
# Processing record 353 of 598 | rietavas
# Processing record 354 of 598 | namibe
# Processing record 355 of 598 | provideniya
# Processing record 356 of 598 | smithers
# Processing record 357 of 598 | evensk
# Processing record 358 of 598 | lashio
# Processing record 359 of 598 | barcelos
# Processing record 360 of 598 | pangoa
# Processing record 361 of 598 | sandpoint
# Processing record 362 of 598 | esperance
# Processing record 363 of 598 | balkhash
# Processing record 364 of 598 | pudozh
# Processing record 365 of 598 | kungurtug
# Processing record 366 of 598 | hauterive
# Processing record 367 of 598 | tabiauea
# City not found. Skipping...
# Processing record 368 of 598 | fairview
# Processing record 369 of 598 | broome
# Processing record 370 of 598 | ozgon
# City not found. Skipping...
# Processing record 371 of 598 | mao
# Processing record 372 of 598 | muros
# Processing record 373 of 598 | saint george
# Processing record 374 of 598 | fort dodge
# Processing record 375 of 598 | bastia
# Processing record 376 of 598 | saint-georges
# Processing record 377 of 598 | kovdor
# Processing record 378 of 598 | port augusta
# Processing record 379 of 598 | waipawa
# Processing record 380 of 598 | mega
# Processing record 381 of 598 | roald
# Processing record 382 of 598 | fare
# Processing record 383 of 598 | capao da canoa
# Processing record 384 of 598 | srednekolymsk
# Processing record 385 of 598 | soloneshnoye
# Processing record 386 of 598 | san vicente
# Processing record 387 of 598 | rungata
# City not found. Skipping...
# Processing record 388 of 598 | yeppoon
# Processing record 389 of 598 | vila velha
# Processing record 390 of 598 | daru
# Processing record 391 of 598 | bintulu
# Processing record 392 of 598 | te anau
# Processing record 393 of 598 | warwick
# Processing record 394 of 598 | zelezna ruda
# Processing record 395 of 598 | chastoozerye
# City not found. Skipping...
# Processing record 396 of 598 | hirara
# Processing record 397 of 598 | beringovskiy
# Processing record 398 of 598 | codrington
# Processing record 399 of 598 | todos santos
# Processing record 400 of 598 | peterhead
# Processing record 401 of 598 | praia da vitoria
# Processing record 402 of 598 | acajutla
# Processing record 403 of 598 | yerbogachen
# Processing record 404 of 598 | north bend
# Processing record 405 of 598 | kaitangata
# Processing record 406 of 598 | usinsk
# Processing record 407 of 598 | kuche
# City not found. Skipping...
# Processing record 408 of 598 | calama
# Processing record 409 of 598 | severodvinsk
# Processing record 410 of 598 | sechura
# Processing record 411 of 598 | kawalu
# Processing record 412 of 598 | ban nahin
# Processing record 413 of 598 | altay
# Processing record 414 of 598 | utila
# City not found. Skipping...
# Processing record 415 of 598 | iracoubo
# Processing record 416 of 598 | krasnyy chikoy
# Processing record 417 of 598 | anloga
# Processing record 418 of 598 | ketchikan
# Processing record 419 of 598 | natal
# Processing record 420 of 598 | lavassaare
# Processing record 421 of 598 | la palma del condado
# Processing record 422 of 598 | kotlyarevskaya
# Processing record 423 of 598 | angatuba
# Processing record 424 of 598 | isangel
# Processing record 425 of 598 | constitucion
# Processing record 426 of 598 | skibbereen
# Processing record 427 of 598 | kahului
# Processing record 428 of 598 | omutinskoye
# City not found. Skipping...
# Processing record 429 of 598 | bumiayu
# Processing record 430 of 598 | corrente
# Processing record 431 of 598 | vao
# Processing record 432 of 598 | kathmandu
# Processing record 433 of 598 | bluefields
# Processing record 434 of 598 | fairbanks
# Processing record 435 of 598 | maymanak
# City not found. Skipping...
# Processing record 436 of 598 | pombia
# Processing record 437 of 598 | faya
# Processing record 438 of 598 | fomboni
# Processing record 439 of 598 | laguna
# Processing record 440 of 598 | marrakesh
# Processing record 441 of 598 | yancheng
# Processing record 442 of 598 | vicuna
# City not found. Skipping...
# Processing record 443 of 598 | warqla
# City not found. Skipping...
# Processing record 444 of 598 | nagarote
# Processing record 445 of 598 | amapa
# Processing record 446 of 598 | maoming
# Processing record 447 of 598 | touros
# Processing record 448 of 598 | necochea
# Processing record 449 of 598 | luzhou
# Processing record 450 of 598 | floro
# Processing record 451 of 598 | nazarovo
# Processing record 452 of 598 | comodoro rivadavia
# Processing record 453 of 598 | nouadhibou
# Processing record 454 of 598 | aswan
# Processing record 455 of 598 | kodiak
# Processing record 456 of 598 | tahta
# City not found. Skipping...
# Processing record 457 of 598 | broken hill
# Processing record 458 of 598 | sola
# Processing record 459 of 598 | karaton
# Processing record 460 of 598 | palabuhanratu
# City not found. Skipping...
# Processing record 461 of 598 | inuvik
# Processing record 462 of 598 | kisanga
# Processing record 463 of 598 | traralgon
# Processing record 464 of 598 | tumannyy
# City not found. Skipping...
# Processing record 465 of 598 | rawannawi
# City not found. Skipping...
# Processing record 466 of 598 | erzin
# Processing record 467 of 598 | baghdad
# Processing record 468 of 598 | tairua
# Processing record 469 of 598 | nuuk
# Processing record 470 of 598 | port-gentil
# Processing record 471 of 598 | hokitika
# Processing record 472 of 598 | nizhniy kuranakh
# Processing record 473 of 598 | maceio
# Processing record 474 of 598 | puerto madryn
# Processing record 475 of 598 | xuddur
# Processing record 476 of 598 | diffa
# Processing record 477 of 598 | biak
# Processing record 478 of 598 | sao caitano
# City not found. Skipping...
# Processing record 479 of 598 | ituni
# City not found. Skipping...
# Processing record 480 of 598 | fortuna
# Processing record 481 of 598 | khislavichi
# Processing record 482 of 598 | goianapolis
# Processing record 483 of 598 | linxia
# Processing record 484 of 598 | tamiahua
# Processing record 485 of 598 | ambodifototra
# City not found. Skipping...
# Processing record 486 of 598 | burnie
# Processing record 487 of 598 | beaupre
# Processing record 488 of 598 | mto wa mbu
# Processing record 489 of 598 | quimper
# Processing record 490 of 598 | gambela
# Processing record 491 of 598 | tartagal
# Processing record 492 of 598 | saldanha
# Processing record 493 of 598 | fort nelson
# Processing record 494 of 598 | husavik
# Processing record 495 of 598 | praia
# Processing record 496 of 598 | taltal
# Processing record 497 of 598 | neyyattinkara
# Processing record 498 of 598 | suntar
# Processing record 499 of 598 | arcachon
# Processing record 500 of 598 | orocovis
# Processing record 501 of 598 | galveston
# Processing record 502 of 598 | shingu
# Processing record 503 of 598 | svetlyy
# City not found. Skipping...
# Processing record 504 of 598 | ola
# Processing record 505 of 598 | ruidoso
# Processing record 506 of 598 | choya
# Processing record 507 of 598 | surt
# Processing record 508 of 598 | usta muhammad
# Processing record 509 of 598 | bedesa
# Processing record 510 of 598 | stara vyzhivka
# Processing record 511 of 598 | yatsushiro
# Processing record 512 of 598 | kloulklubed
# Processing record 513 of 598 | san francisco del mar
# Processing record 514 of 598 | ostrovnoy
# Processing record 515 of 598 | pak phanang
# Processing record 516 of 598 | samalaeulu
# City not found. Skipping...
# Processing record 517 of 598 | shakawe
# Processing record 518 of 598 | okhotsk
# Processing record 519 of 598 | carauari
# Processing record 520 of 598 | peniche
# Processing record 521 of 598 | abu kamal
# Processing record 522 of 598 | rosetta
# Processing record 523 of 598 | samarkand
# Processing record 524 of 598 | nestorion
# City not found. Skipping...
# Processing record 525 of 598 | alotau
# City not found. Skipping...
# Processing record 526 of 598 | matagami
# Processing record 527 of 598 | maralal
# Processing record 528 of 598 | cheuskiny
# City not found. Skipping...
# Processing record 529 of 598 | palmas
# Processing record 530 of 598 | bengkulu
# City not found. Skipping...
# Processing record 531 of 598 | belen
# Processing record 532 of 598 | sungaipenuh
# Processing record 533 of 598 | coquimbo
# Processing record 534 of 598 | nouakchott
# Processing record 535 of 598 | dakoro
# Processing record 536 of 598 | mahon
# Processing record 537 of 598 | kamenka
# Processing record 538 of 598 | norwalk
# Processing record 539 of 598 | ondorhaan
# City not found. Skipping...
# Processing record 540 of 598 | kampong thum
# Processing record 541 of 598 | iralaya
# Processing record 542 of 598 | leningradskiy
# Processing record 543 of 598 | tiznit
# Processing record 544 of 598 | mehamn
# Processing record 545 of 598 | itamaraca
# Processing record 546 of 598 | tablac
# Processing record 547 of 598 | mingshui
# Processing record 548 of 598 | ulaangom
# Processing record 549 of 598 | saint-francois
# Processing record 550 of 598 | lompoc
# Processing record 551 of 598 | amderma
# City not found. Skipping...
# Processing record 552 of 598 | faanui
# Processing record 553 of 598 | maraa
# Processing record 554 of 598 | tuatapere
# Processing record 555 of 598 | rafaela
# Processing record 556 of 598 | ugoofaaru
# Processing record 557 of 598 | duldurga
# Processing record 558 of 598 | ortakoy
# Processing record 559 of 598 | lofthus
# Processing record 560 of 598 | saint-pierre
# Processing record 561 of 598 | mecca
# Processing record 562 of 598 | kumphawapi
# Processing record 563 of 598 | mumford
# Processing record 564 of 598 | talnakh
# Processing record 565 of 598 | seljord
# Processing record 566 of 598 | bandarban
# Processing record 567 of 598 | englewood
# Processing record 568 of 598 | moussoro
# Processing record 569 of 598 | utete
# Processing record 570 of 598 | rudolstadt
# Processing record 571 of 598 | bambanglipuro
# Processing record 572 of 598 | susanville
# Processing record 573 of 598 | novobirilyussy
# Processing record 574 of 598 | saint anthony
# Processing record 575 of 598 | rudbar
# City not found. Skipping...
# Processing record 576 of 598 | ballina
# Processing record 577 of 598 | baykit
# Processing record 578 of 598 | omboue
# Processing record 579 of 598 | dolores
# Processing record 580 of 598 | kingsville
# Processing record 581 of 598 | kolokani
# Processing record 582 of 598 | kuzhorskaya
# Processing record 583 of 598 | puerto del rosario
# Processing record 584 of 598 | savannah bight
# Processing record 585 of 598 | khor
# Processing record 586 of 598 | at-bashi
# Processing record 587 of 598 | santo tomas
# Processing record 588 of 598 | greenwood
# Processing record 589 of 598 | victoria
# Processing record 590 of 598 | guliston
# Processing record 591 of 598 | felidhoo
# City not found. Skipping...
# Processing record 592 of 598 | minudasht
# Processing record 593 of 598 | sug-aksy
# City not found. Skipping...
# Processing record 594 of 598 | svetlogorsk
# Processing record 595 of 598 | howard springs
# Processing record 596 of 598 | gornyy
# Processing record 597 of 598 | cervo
# Processing record 598 of 598 | ust-nera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export the city data into a .csv
city_series = pd.Series(city)
city_series.to_csv(output_data_file, index=False)

# %%
# create a data frame from city, country, latitude, longitude, time_data, temperature, humidity, cloudiness, wind_speed
weather_dict = {
    "City": city,
    "Country": country,
    "Lat": latitude,
    "Lng": longitude,
    "Date": time_data,
    "Max Temp": temperature,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          529
# Cloudiness    529
# Country       529
# Date          529
# Humidity      529
# Lat           529
# Lng           529
# Max Temp      529
# Wind Speed    529
# dtype: int64

# %%
# Display the DataFrame
weather_data.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0           Dikson          64      RU  1547956549       100  73.51  80.55
# 1      Port Alfred          92      ZA  1547955951       100 -33.59  26.89
# 2          Tubuala          20      PA  1547953200        78   9.52 -79.03
# 3        Taoudenni           0      ML  1547955976        41  22.68  -3.98
# 4  Verkhnyaya Inta          32      RU  1547955993        65  65.99  60.32
#
#    Max Temp  Wind Speed
# 0      6.62       10.98
# 1     61.56        5.61
# 2     78.80        2.24
# 3     36.59        3.60
# 4      2.84        2.59

# %%
# Export the weather_data DataFrame into a .csv
weather_data.to_csv("output_data/weather_data.csv", index=False, header=True)

# %%
# Convert Date into MM/DD/YY format
DM = lambda x: str(x) if x > 9 else f"0{x}"
YY = lambda year: str(year)[-2:]
t_mean = time.gmtime(weather_data.Date.mean())
date_plot = f"{DM(t_mean[1])}/{DM(t_mean[2])}/{YY(t_mean[0])}"

#This code was to verify that all data points have the same date MM/DD/YYY:
#t_min = time.gmtime(weather_data.Date.min())
#print(t_min)
#print(f"min: {DM(t_min[1])}/{DM(t_min[2])}/{YY(t_min[0])}")
#t_max = time.gmtime(weather_data.Date.max())
#print(t_max)
#print(f"max: {DM(t_max[1])}/{DM(t_max[2])}/{YY(t_max[0])}")'''

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build figure
temperature_plot = plt.scatter(weather_data['Lat'], weather_data['Max Temp'], facecolors='lightskyblue',
                               linewidths=1, edgecolors='black', alpha=0.75)
plt.title(f"City Latitude vs. Max Temperature ({date_plot})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.show()

# Save Figure
plt.savefig("output_data/latitude_temperature_plot.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build figure
humidity_plot = plt.scatter(weather_data['Lat'], weather_data['Humidity'], facecolors='lightskyblue',
                               linewidths=1, edgecolors='black', alpha=0.75)
plt.title(f"City Latitude vs. Humidity ({date_plot})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.show()

# Save Figure
plt.savefig("output_data/latitude_humidity_plot.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build figure
cloudiness_plot = plt.scatter(weather_data['Lat'], weather_data['Cloudiness'], facecolors='lightskyblue',
                               linewidths=1, edgecolors='black', alpha=0.75)
plt.title(f"City Latitude vs. Cloudiness ({date_plot})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show()

# Save Figure
plt.savefig("output_data/latitude_cloudiness_plot.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
wind_speed_plot = plt.scatter(weather_data['Lat'], weather_data['Wind Speed'], facecolors='lightskyblue',
                               linewidths=1, edgecolors='black', alpha=0.75)
plt.title(f"City Latitude vs. Wind Speed ({date_plot})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show()

# Save Figure
plt.savefig("output_data/latitude_wind_speed_plot.png")
